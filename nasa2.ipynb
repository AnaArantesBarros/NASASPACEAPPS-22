# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaArantesBarros/NASASPACEAPPS-22/blob/main/nasa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install lightkurve --quiet
import lightkurve as lk
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#https://heasarc.gsfc.nasa.gov/docs/tess/
#https://mast.stsci.edu/portal/Mashup/Clients/Mast/Portal.html
# Out:
#      |████████████████████████████████| 247 kB 25.6 MB/s
#      |████████████████████████████████| 4.5 MB 49.4 MB/s
#      |████████████████████████████████| 98 kB 6.4 MB/s
#      |████████████████████████████████| 41 kB 164 kB/s
#      |████████████████████████████████| 832 kB 79.6 MB/s
#      |████████████████████████████████| 48 kB 4.4 MB/s
#      |████████████████████████████████| 4.0 MB 74.9 MB/s
# ...

# %%
search_result_q2 = lk.search_lightcurve('06:45:08.880 -16:42:56.68', sector=33).download()
len(search_result_q2) 
#lc = pixelfile.to_lightcurve(aperture_mask='all');
#lc = lc.remove_outliers(sigma=0)#.flatten()
#lc.plot()
# Out:
# 3485

# %%
search_result_q2.plot()

# %%
search_result_q2 = lk.search_lightcurve('07:39:18.052 +05:13:29.77', sector = 34)[1].download()
len(search_result_q2) 
#lc = pixelfile.to_lightcurve(aperture_mask='all');
#lc = lc.remove_outliers(sigma=0)#.flatten()
#lc.plot()
# Out:
# 3474

# %%
search_result_q2.plot()

# %%
search_result_q2 = lk.search_lightcurve('04:15:21.539 -07:39:20.72', sector = 32)[2].download()
len(search_result_q2) 
#lc = pixelfile.to_lightcurve(aperture_mask='all');
#lc = lc.remove_outliers(sigma=0)#.flatten()
#lc.plot()
# Out:
# 17977

# %%
search_result_q2.plot()

# %%
search_result_q2 = lk.search_lightcurve('04:30:02.412 +58:58:47.97', sector= 19)[1].download()
len(search_result_q2) 
#search_result_q2 
#lc = pixelfile.to_lightcurve(aperture_mask='all');
#lc = lc.remove_outliers(sigma=0)#.flatten()
#lc.plot()
# Out:
# 1122

# %%
search_result_q2.plot()

# %%
search_result_q2 = lk.search_lightcurve('17:48:07.993 +70:52:35.92',sector = 55)[1].download()
len(search_result_q2) 
#search_result_q2 
#lc = pixelfile.to_lightcurve(aperture_mask='all');
#lc = lc.remove_outliers(sigma=0)#.flatten()
#lc.plot()
# Out:
# 18882

# %%
search_result_q2.plot()

# %%
search_result_q2 = lk.search_lightcurve('05:54:10.813 -50:21:45.18',sector=34)[2].download()
len(search_result_q2) 
#search_result_q2 
#lc = pixelfile.to_lightcurve(aperture_mask='all');
#lc = lc.remove_outliers(sigma=0)#.flatten()
# Out:
# 3474

# %%
search_result_q2.plot()

# %%
search_result_q2 = lk.search_lightcurve('17:09:31.544 +43:40:52.77',sector=53)[1].download()
len(search_result_q2) 
#search_result_q2 
#lc = pixelfile.to_lightcurve(aperture_mask='all');
#lc = lc.remove_outliers(sigma=0)#.flatten()
# Out:
# 17306

# %%
search_result_q2.plot()
